# %%
# %load_ext Cython
# %time
from gensim.models import doc2vec 
import nltk 
import re 
import pandas as pd
import numpy as np
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs

# %%
####load data and save as a txt####
raw_data=pd.read_csv("data.csv")
np.savetxt(r'review.txt', raw_data['review'], fmt='%s')

# %%
raw_data
# Out:
#                       category                           rating  \
# 0                       Action  Rated 5 stars out of five stars
# 1                Communication  Rated 5 stars out of five stars
# 2                      Finance  Rated 5 stars out of five stars
# 3                Communication  Rated 5 stars out of five stars
# 4     SportsAction & Adventure  Rated 2 stars out of five stars
# 5                       Action  Rated 5 stars out of five stars
# 6                       Action  Rated 4 stars out of five stars
# 7                       Action  Rated 5 stars out of five stars
# 8                       Action  Rated 4 stars out of five stars
# 9                       Action  Rated 5 stars out of five stars
# 10                      Action  Rated 2 stars out of five stars
# 11                      Action  Rated 3 stars out of five stars
# 12                      Action  Rated 5 stars out of five stars
# 13                      Action  Rated 5 stars out of five stars
# 14               Music & Audio  Rated 1 stars out of five stars
# 15               Communication  Rated 5 stars out of five stars
# 16               Communication  Rated 5 stars out of five stars
# 17               Communication  Rated 5 stars out of five stars
# 18               Communication  Rated 5 stars out of five stars
# 19               Communication  Rated 4 stars out of five stars
# 20               Communication  Rated 4 stars out of five stars
# 21               Communication  Rated 1 stars out of five stars
# 22               Communication  Rated 1 stars out of five stars
# 23               Communication  Rated 1 stars out of five stars
# 24                     Finance  Rated 3 stars out of five stars
# 25                     Finance  Rated 5 stars out of five stars
# 26                     Finance  Rated 4 stars out of five stars
# 27                     Finance  Rated 1 stars out of five stars
# 28                     Finance  Rated 1 stars out of five stars
# 29                     Finance  Rated 5 stars out of five stars
# ...                        ...                              ...
# 8941                    Social  Rated 1 stars out of five stars
# 8942                    Social  Rated 1 stars out of five stars
# 8943             Entertainment  Rated 4 stars out of five stars
# 8944             Entertainment  Rated 4 stars out of five stars
# 8945             Entertainment  Rated 5 stars out of five stars
# 8946             Entertainment  Rated 5 stars out of five stars
# 8947             Entertainment  Rated 4 stars out of five stars
# 8948             Entertainment  Rated 4 stars out of five stars
# 8949                    Puzzle  Rated 3 stars out of five stars
# 8950                    Puzzle  Rated 3 stars out of five stars
# 8951                    Puzzle  Rated 2 stars out of five stars
# 8952                     Tools  Rated 5 stars out of five stars
# 8953                     Tools  Rated 5 stars out of five stars
# 8954                    Social  Rated 5 stars out of five stars
# 8955                    Social  Rated 5 stars out of five stars
# 8956                    Social  Rated 1 stars out of five stars
# 8957             Entertainment  Rated 4 stars out of five stars
# 8958             Entertainment  Rated 4 stars out of five stars
# 8959             Entertainment  Rated 5 stars out of five stars
# 8960             Entertainment  Rated 5 stars out of five stars
# 8961             Entertainment  Rated 5 stars out of five stars
# 8962             Entertainment  Rated 3 stars out of five stars
# 8963                    Puzzle  Rated 2 stars out of five stars
# 8964                    Puzzle  Rated 4 stars out of five stars
# 8965                    Puzzle  Rated 5 stars out of five stars
# 8966             Entertainment  Rated 5 stars out of five stars
# 8967             Entertainment  Rated 5 stars out of five stars
# 8968             Entertainment  Rated 1 stars out of five stars
# 8969             Entertainment  Rated 4 stars out of five stars
# 8970             Entertainment  Rated 5 stars out of five stars
#
#                       name                             app  \
# 0         Kalito Doughnuts                    Color Switch
# 1       Jonathan Macabuhay                       Messenger
# 2            Lisa Resendez                          IRS2Go
# 3           3rd Degree Inc  Marco Polo Video Walkie Talkie
# 4            Morgan Wilson               Madden NFL Mobile
# 5           Arrun Gaydhani                    Color Switch
# 6             Fatima Damir                    Color Switch
# 7             Versha Verma                    Color Switch
# 8             Trisha Gupta                    Color Switch
# 9                anonymous                    Color Switch
# 10         randicia mcneil                    Color Switch
# 11             21 Crybabys                    Color Switch
# 12          Shravani Jilla                    Color Switch
# 13              amya brown                    Color Switch
# 14        Riccardo Rovesta      SoundCloud - Music & Audio
# 15      Md.zidan Md.shadin                       Messenger
# 16            janaiah Jani                       Messenger
# 17     Dakota Vaillencourt                       Messenger
# 18           Tim Squadrito                       Messenger
# 19         Franz Carandang                       Messenger
# 20         Miguel Carvalho                       Messenger
# 21          Michelle Scott                       Messenger
# 22          dillang geiser                       Messenger
# 23          Eduard Horváth                       Messenger
# 24               Charley B                          IRS2Go
# 25           Julie Collins                          IRS2Go
# 26              Adam Moore                          IRS2Go
# 27         Jessica Stetler                          IRS2Go
# 28         Krissy Brassell                          IRS2Go
# 29           Karina Byerly                          IRS2Go
# ...                    ...                             ...
# 8941             Ahmad Aki                        Facebook
# 8942                  nxl_                        Facebook
# 8943         May Valentine   Bitmoji – Your Personal Emoji
# 8944       Melissa Forward   Bitmoji – Your Personal Emoji
# 8945        Karen Nicholas   Bitmoji – Your Personal Emoji
# 8946         Leslie Winans   Bitmoji – Your Personal Emoji
# 8947             anonymous   Bitmoji – Your Personal Emoji
# 8948    Bernardo Dominguez   Bitmoji – Your Personal Emoji
# 8949           Susan James             Bubble Witch 3 Saga
# 8950       Chloe McCreadie             Bubble Witch 3 Saga
# 8951        Martin Fradley             Bubble Witch 3 Saga
# 8952          Sergio Angel      DFNDR: Antivirus & Cleaner
# 8953  Clyde Ashley Sherman      DFNDR: Antivirus & Cleaner
# 8954         Anibel Abalin                        Facebook
# 8955         Guru Bachchan                        Facebook
# 8956           Akshay Abhi                        Facebook
# 8957             A Pacheco   Bitmoji – Your Personal Emoji
# 8958           Bonita Love   Bitmoji – Your Personal Emoji
# 8959            Courtney G   Bitmoji – Your Personal Emoji
# 8960   Brittiney Etheridge   Bitmoji – Your Personal Emoji
# 8961             safia ali   Bitmoji – Your Personal Emoji
# 8962             Roli Good   Bitmoji – Your Personal Emoji
# 8963  Michelle Breitkreutz             Bubble Witch 3 Saga
# 8964               RC COOK             Bubble Witch 3 Saga
# 8965          Amanda Scott             Bubble Witch 3 Saga
# 8966      La'Tisha Bandele   Bitmoji – Your Personal Emoji
# 8967             anonymous   Bitmoji – Your Personal Emoji
# 8968           Ayla Sindel   Bitmoji – Your Personal Emoji
# 8969         Sequoyah Hawk   Bitmoji – Your Personal Emoji
# 8970            Amor Renee   Bitmoji – Your Personal Emoji
#
#                             tp  \
# 0     Top Free in Android Apps
# 1     Top Free in Android Apps
# 2     Top Free in Android Apps
# 3     Top Free in Android Apps
# 4     Top Free in Android Apps
# 5     Top Free in Android Apps
# 6     Top Free in Android Apps
# 7     Top Free in Android Apps
# 8     Top Free in Android Apps
# 9     Top Free in Android Apps
# 10    Top Free in Android Apps
# 11    Top Free in Android Apps
# 12    Top Free in Android Apps
# 13    Top Free in Android Apps
# 14    Top Free in Android Apps
# 15    Top Free in Android Apps
# 16    Top Free in Android Apps
# 17    Top Free in Android Apps
# 18    Top Free in Android Apps
# 19    Top Free in Android Apps
# 20    Top Free in Android Apps
# 21    Top Free in Android Apps
# 22    Top Free in Android Apps
# 23    Top Free in Android Apps
# 24    Top Free in Android Apps
# 25    Top Free in Android Apps
# 26    Top Free in Android Apps
# 27    Top Free in Android Apps
# 28    Top Free in Android Apps
# 29    Top Free in Android Apps
# ...                        ...
# 8941  Top Free in Android Apps
# 8942  Top Free in Android Apps
# 8943  Top Free in Android Apps
# 8944  Top Free in Android Apps
# 8945  Top Free in Android Apps
# 8946  Top Free in Android Apps
# 8947  Top Free in Android Apps
# 8948  Top Free in Android Apps
# 8949  Top Free in Android Apps
# 8950  Top Free in Android Apps
# 8951  Top Free in Android Apps
# 8952  Top Free in Android Apps
# 8953  Top Free in Android Apps
# 8954  Top Free in Android Apps
# 8955  Top Free in Android Apps
# 8956  Top Free in Android Apps
# 8957  Top Free in Android Apps
# 8958  Top Free in Android Apps
# 8959  Top Free in Android Apps
# 8960  Top Free in Android Apps
# 8961  Top Free in Android Apps
# 8962  Top Free in Android Apps
# 8963  Top Free in Android Apps
# 8964  Top Free in Android Apps
# 8965  Top Free in Android Apps
# 8966  Top Free in Android Apps
# 8967  Top Free in Android Apps
# 8968  Top Free in Android Apps
# 8969  Top Free in Android Apps
# 8970  Top Free in Android Apps
#
#                                                  review               date  \
# 0     This is the type of game you can just pickup a...   February 9, 2017
# 1     Very nice to meet you at work and I have to go...  February 11, 2017
# 2     To the ones saying this app keeps giving a mes...   January 24, 2017
# 3     But it constantly crashes!  I have reinstalled...   February 7, 2017
# 4     I don't like being overwhelmed by all these he...   January 20, 2017
# 5     Perfect example of what a mobile game should b...  February 10, 2017
# 6     It's good but the ads are annoying. I like how...  February 10, 2017
# 7     Its a commentable game. It is not too gud as t...  February 10, 2017
# 8     It is a excellent game. But why is Google givi...  February 11, 2017
# 9     This game is so much fun to play in. You get t...   February 9, 2017
# 10    Frankly, the game makes you an addict. However...   February 9, 2017
# 11    Would rate 5 stars but whenever I look at all ...   February 9, 2017
# 12    Awesome game They always keep updating and u a...   February 9, 2017
# 13    Really love your game. I am such a big fan 4 c...   February 9, 2017
# 14    A few months ago I uninstalled the app because...  February 10, 2017
# 15                                         Help tansfet  February 10, 2017
# 16                                             Good app  February 11, 2017
# 17    This app is fantastically convenient. The fact...   February 7, 2017
# 18    Good app, useful, easy. Sure it didn't need to...   February 8, 2017
# 19    Not Perfect. But the fact that almost everyone...   February 8, 2017
# 20    Messenger is a quite good and versatile messag...   February 9, 2017
# 21    I hate the fact it has to be installed on my p...  February 10, 2017
# 22    Well, its irritating that while going through ...  February 10, 2017
# 23    The most annoying app I know,  loaded with ton...  February 10, 2017
# 24    Does not work, when website does. For some rea...   February 4, 2017
# 25    For everyone who's saying that the reason some...   February 8, 2017
# 26    If you people saying no dependent tax refunds ...   February 9, 2017
# 27    "Information entered not correct". I'm typing ...   January 29, 2017
# 28    At first it was freezing for two daya. Now it ...  February 10, 2017
# 29    Having to do 11 years of reporting & filing- t...   January 21, 2017
# ...                                                 ...                ...
# 8941                                             Crash!   February 8, 2017
# 8942                                             So bad   February 7, 2017
# 8943  A darker purple would be better than just that...   January 15, 2017
# 8944  The actual app itself is great. The only thing...   January 24, 2017
# 8945  I love it. It so much fun  it's addicting. The...   February 4, 2017
# 8946  I love my avatar, but I just wish there were m...   January 14, 2017
# 8947  I want more hair options as far as style and c...   January 25, 2017
# 8948  I LOVE this app especially using this app for ...   February 7, 2017
# 8949  Whilst I'm enjoying the challenge, it is expen...   February 8, 2017
# 8950  I would  have given this game 5 stars if you h...   February 6, 2017
# 8951  I have had so many of these games and this is ...   February 6, 2017
# 8952                                   It's really good  February 10, 2017
# 8953                           Actually removes viruses  February 10, 2017
# 8954                                       Lab this app   February 8, 2017
# 8955                                          Thank you   February 9, 2017
# 8956                                   Supper Skooteeee   February 9, 2017
# 8957  I like it alot...i cant wait to start sending ...   January 26, 2017
# 8958  I just love this! You will be delightfully sur...   January 28, 2017
# 8959  Love this app. And the fact that she looks lik...   February 5, 2017
# 8960  I love my very own Avatar I created! So cool.....   February 9, 2017
# 8961  I love using the bitmoji app for snapchat and ...   January 27, 2017
# 8962  The app is fun and I like most of the sayings ...   January 26, 2017
# 8963  I love playing the game but hate that the road...   February 7, 2017
# 8964  Bubble Witch 3 is yet another great, entertain...   February 6, 2017
# 8965  Much more fun than the previous two versions, ...   February 4, 2017
# 8966  Everyone waits to see my visual text, lol! Whe...   January 18, 2017
# 8967  You should definitely get it! It is awesome. I...   January 31, 2017
# 8968  Everytime I try create one a message box pops ...   January 31, 2017
# 8969  Make it to where we can customize the clothing...   January 27, 2017
# 8970  I adore this app. The only thing I wish could ...   January 13, 2017
#
#                     brand
# 0           Fortafy Games
# 1                Facebook
# 2                     IRS
# 3     Joya Communications
# 4         ELECTRONIC ARTS
# 5           Fortafy Games
# 6           Fortafy Games
# 7           Fortafy Games
# 8           Fortafy Games
# 9           Fortafy Games
# 10          Fortafy Games
# 11          Fortafy Games
# 12          Fortafy Games
# 13          Fortafy Games
# 14             SoundCloud
# 15               Facebook
# 16               Facebook
# 17               Facebook
# 18               Facebook
# 19               Facebook
# 20               Facebook
# 21               Facebook
# 22               Facebook
# 23               Facebook
# 24                    IRS
# 25                    IRS
# 26                    IRS
# 27                    IRS
# 28                    IRS
# 29                    IRS
# ...                   ...
# 8941             Facebook
# 8942             Facebook
# 8943            Bitstrips
# 8944            Bitstrips
# 8945            Bitstrips
# 8946            Bitstrips
# 8947            Bitstrips
# 8948            Bitstrips
# 8949                 King
# 8950                 King
# 8951                 King
# 8952                PSafe
# 8953                PSafe
# 8954             Facebook
# 8955             Facebook
# 8956             Facebook
# 8957            Bitstrips
# 8958            Bitstrips
# 8959            Bitstrips
# 8960            Bitstrips
# 8961            Bitstrips
# 8962            Bitstrips
# 8963                 King
# 8964                 King
# 8965                 King
# 8966            Bitstrips
# 8967            Bitstrips
# 8968            Bitstrips
# 8969            Bitstrips
# 8970            Bitstrips
#
# [8971 rows x 8 columns]

# %%
def split_sentence(sentence): 
    return re.split('\W+', sentence) 
class MyDocs(object): 
    def __iter__(self):
        for i, text in enumerate(open("review.txt")): 
            yield doc2vec.LabeledSentence(words=split_sentence(text), tags=['%s' % i]) 
# Train the doc2vec model cdef 
mydocs = MyDocs() 
model = doc2vec.Doc2Vec(mydocs, size = 200, window = 8, min_count = 5, workers = 4) 
model.save('review.model')

# %%
print model.most_similar(positive=["game", "great"], negative=["bad"], topn=3)
# Out:
# [('app', 0.7457967400550842), ('job', 0.6689680814743042), ('Love', 0.6604655981063843)]

# %%
# Calculate the cosine similarity between two vecotrs 
def cossim(v1, v2): 
    return np.dot(v1, v2) / np.sqrt(np.dot(v1, v1)) / np.sqrt(np.dot(v2, v2)) 
# Get the specific line of the review text file
def get_line(filename, n): 
    with open(filename) as f: 
        for i, e in enumerate(f): 
            if i == n: return e 
# Calculate the vector of input text according to our training model 
input_text = "great puzzle game" 
input_vec = model.infer_vector(split_sentence(input_text))

# %%
cossims_with_input = map(lambda v: cossim(input_vec, v), model.docvecs)

# %%
# Get the index of top n most similar review 
def argmaxn(l, n): 
    l_copy = list(l) 
    args = [] 
    for i in range(n): 
        arg = np.argmax(l_copy) 
        args.append(arg) 
        l_copy[arg] = -float('inf') 
        return args

# %%
# Print the reviews with the highest cosine similarity values 
sim_ids = argmaxn(cossims_with_input, 3) 
for i in range(len(sim_ids)): 
    print "(Review-%s, Similarity:%.4f):" % (sim_ids[i] + 1, cossims_with_input[sim_ids[i]]),\
    get_line('review.txt', sim_ids[i])
# Out:
# (Review-6784, Similarity:0.8765): The game is very fun, but the amount of little bugs in the game bothers me; tricks wont register or multiplier decides to not go up. I love the game but just wish it would run smooth, especially after its been out this long

# %%
# Construct a data frame with the Appname and document-vectors of all archived reviews 
raw_data['Textvec'] = model.docvecs 
# Compute similarity scores between the input text and the hotels (defined here as the cosine similarity between 
# the document-vector of the input text and the sum/mean of the document-vectors of all the reviews of a hotel -- 
# no difference between sum and mean) 
app_cossims = raw_data.groupby('app').agg(lambda v: cossim(np.sum(v), input_vec))
# Print the reviews with the highest similarity scores 
sim_ids = argmaxn(app_cossims['Textvec'], 3) 
for i in range(len(sim_ids)): 
    app = app_cossims.index[sim_ids[i]] 
    print "App name is: %s" % app, ", and the similarity is equal to: %.4f," % app_cossims.Textvec[app]
# Out:
# App name is: Block! Hexa Puzzle , and the similarity is equal to: 0.7963,
